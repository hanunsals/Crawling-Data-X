# %% [markdown]
# # ***CRAWLING DATA X (TWITTER) KEYWORD : BANGKIT ACADEMY***

# %%
# !pip install pandas
# !curl -sL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# ...
# 2024-03-17 23:47:16 - Installing pre-requisites
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [737 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,961 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
data = 'data_BangkitAcademy.csv'
search_keyword = 'bangkit academy until:2024-03-18 since:2023-01-01'
limit = 1000

# !npx --yes tweet-harvest@2.2.8 -o "{data}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import pandas as pd

data = pd.read_csv("/content/tweets-data/data_BangkitAcademy.csv", sep=";")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527 entries, 0 to 526
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           527 non-null    object
#  1   id_str               527 non-null    int64
#  2   full_text            527 non-null    object
#  3   quote_count          527 non-null    int64
#  4   reply_count          527 non-null    int64
#  5   retweet_count        527 non-null    int64
#  6   favorite_count       527 non-null    int64
#  7   lang                 527 non-null    object
#  8   user_id_str          527 non-null    int64
#  9   conversation_id_str  527 non-null    int64
#  10  username             527 non-null    object
#  11  tweet_url            527 non-null    object
# dtypes: int64(7), object(5)
# memory usage: 49.5+ KB

# %%
data.head(550)
# Out:
#                          created_at               id_str  \
# 0    Sun Mar 17 21:15:20 +0000 2024  1769472611208380731
# 1    Fri Mar 15 20:48:14 +0000 2024  1768741014217585138
# 2    Fri Mar 15 16:55:41 +0000 2024  1768682493933445627
# 3    Fri Mar 15 16:32:06 +0000 2024  1768676558062125246
# 4    Fri Mar 15 07:03:15 +0000 2024  1768533402284859675
# ..                              ...                  ...
# 522  Sun Jan 15 12:00:01 +0000 2023  1614593241688735744
# 523  Thu Jan 12 14:54:37 +0000 2023  1613550016932773888
# 524  Sat Jan 07 05:45:17 +0000 2023  1611599834414477313
# 525  Thu Jan 12 06:06:37 +0000 2023  1613417144674570244
# 526  Tue Jan 03 05:26:16 +0000 2023  1610145498543063040
#
#                                              full_text  quote_count  \
# 0    @gasabardrakoran sangat benar, mending nama pr...            0
# 1    [cm] permisi, ada yang ikut bangkit academy ba...            0
# 2                  #bangkitacademy #bangkitacademy2024            0
# ...
